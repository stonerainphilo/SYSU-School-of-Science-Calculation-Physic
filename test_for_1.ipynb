# %%
import numpy as np

from sklearn import datasets, linear_model
from sklearn.preprocessing import PolynomialFeatures

from matplotlib import pyplot as plt, rcParams
fig = plt.figure(figsize=(8,6))

N_train=100
sigma_train=1;
N_test=20
sigam_test=sigma_train

max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test=sigam_test*np.random.randn(N_test)
y_test=2*x_test+s_test
y_test_10th=2*x_test-10*x_test**5+15*x_test**10+s_test
x=np.linspace(0.05,0.95,N_train)
s = sigma_train*np.random.randn(N_train)

y=2*x+s

#Tenth order
y_10th=2*x-10+x**5+15*x**10+s

p1=plt.plot(x,y,'o', ms=8, alpha=0.5, label='training')

clf=linear_model.LinearRegression()

clf.fit(x[:, np.newaxis], y)

xplot=np.linspace(0.02, 0.98, 200)
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')
poly3 = PolynomialFeatures(degree=3)
poly10=PolynomialFeatures(degree=10)

X=poly3.fit_transform(x[:, np.newaxis])
X10=poly10.fit_transform(x[:, np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
clf10=linear_model.LinearRegression()
clf10.fit(X10,y)

Xplot=poly3.fit_transform(xplot[:, np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly3')


plt.legend(loc='best')
plt.ylim([-7,7])
plt.xlabel("x")
plt.ylabel("y")
Title="n=%i, $\sigma=%.2f$"%(N_train, sigma_train)
plt.title(Title+"(train)")

filename_train="train-linhear_N=%i_noise=%.2f.pdf"%(N_train, sigma_train)
plt.savefig(filename_train)
plt.grid()
plt.show()

# %%
import numpy as np

from sklearn import datasets, linear_model
from sklearn.preprocessing import PolynomialFeatures

from matplotlib import pyplot as plt, rcParams
fig = plt.figure(figsize=(8,6))

N_train=100
sigma_train=1;
N_test=20
sigam_test=sigma_train

max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test=sigam_test*np.random.randn(N_test)
y_test=2*x_test+s_test
y_test_10th=2*x_test-10*x_test**5+15*x_test**10+s_test
x=np.linspace(0.05,0.95,N_train)
s = sigma_train*np.random.randn(N_train)

y=2*x+s

#Tenth order
y_10th=2*x-10+x**5+15*x**10+s

p1=plt.plot(x,y,'o', ms=8, alpha=0.5, label='training')

clf=linear_model.LinearRegression()

clf.fit(x[:, np.newaxis], y)

xplot=np.linspace(0.02, 0.98, 200)
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')
poly3 = PolynomialFeatures(degree=3)
poly10=PolynomialFeatures(degree=10)

X=poly3.fit_transform(x[:, np.newaxis])
X10=poly10.fit_transform(x[:, np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
clf10=linear_model.LinearRegression()
clf10.fit(X10,y)

Xplot=poly3.fit_transform(xplot[:, np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly3')
X10plot=poly10.fit_transform(xplot[:, np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(X10plot), label='Poly10')



plt.legend(loc='best')
plt.ylim([-7,7])
plt.xlabel("x")
plt.ylabel("y")
Title="n=%i, $\sigma=%.2f$"%(N_train, sigma_train)
plt.title(Title+"(train)")

filename_train="train-linhear_N=%i_noise=%.2f.pdf"%(N_train, sigma_train)
plt.savefig(filename_train)
plt.grid()
plt.show()

# %%
import numpy as np

from sklearn import datasets, linear_model
from sklearn.preprocessing import PolynomialFeatures

from matplotlib import pyplot as plt, rcParams
fig = plt.figure(figsize=(8,6))

N_train=100
sigma_train=1
N_test=2000
sigam_test=sigma_train

max_x=1.2
x_test=max_x*np.random.random(N_test)
s_test=sigam_test*np.random.randn(N_test)
y_test=2*x_test+s_test
y_test_10th=2*x_test-10*x_test**5+15*x_test**10+s_test
x=np.linspace(0.05,0.95,N_train)
s = sigma_train*np.random.randn(N_train)

y=2*x+s

#Tenth order
y_10th=2*x-10*x**5+15*x**10+s

p1=plt.plot(x,y,'o', ms=8, alpha=0.5, label='training')

clf=linear_model.LinearRegression()

clf.fit(x[:, np.newaxis], y)

xplot=np.linspace(0.02, 0.98, 200)
linear_plot=plt.plot(xplot, clf.predict(xplot[:, np.newaxis]), label='Linear')
poly3 = PolynomialFeatures(degree=3)
poly10=PolynomialFeatures(degree=10)

X=poly3.fit_transform(x[:, np.newaxis])
X3=poly3.fit_transform(x[:, np.newaxis])
X10=poly10.fit_transform(x[:, np.newaxis])
clf3 = linear_model.LinearRegression()
clf3.fit(X,y)
clf10=linear_model.LinearRegression()
clf10.fit(X10,y)

X3=poly3.fit_transform(x[:, np.newaxis])
X10=poly10.fit_transform(x[:, np.newaxis])
Xplot=poly3.fit_transform(xplot[:, np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly3')
X10plot=poly10.fit_transform(xplot[:, np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(X10plot), label='Poly10')



plt.legend(loc='best')
plt.ylim([-7,7])
plt.xlabel("x")
plt.ylabel("y")
Title="n=%i, $\sigma=%.2f$"%(N_train, sigma_train)
plt.title(Title+"(train)")

filename_train="train-linhear_N=%i_noise=%.2f.pdf"%(N_train, sigma_train)
plt.savefig(filename_train)
plt.grid()
plt.show()

x_plot=np.linspace(0,max_x, 200)
X3=poly3.fit_transform(x[:, np.newaxis])
X10=poly10.fit_transform(x[:, np.newaxis])
Xplot=poly3.fit_transform(xplot[:, np.newaxis])
poly3_plot=plt.plot(xplot, clf3.predict(Xplot), label='Poly3')
X10plot=poly10.fit_transform(xplot[:, np.newaxis])
poly10_plot=plt.plot(xplot, clf10.predict(X10plot), label='Poly10')
X3=poly3.fit_transform(x[:, np.newaxis])
X10=poly10.fit_transform(x[:, np.newaxis])

fig=plt.figure(figsize=(8,6))
p1=plt.plot(x_test,y_test, 'o', ms=10, alpha=0.5, label='test data')
p2=plt.plot(x_plot, clf.predict(x_plot[:, np.newaxis]), lw=2, label='linear')
p3=plt.plot(x_plot, clf3.predict(Xplot), lw=2, label='3rd order')
p4=plt.plot(x_plot, clf10.predict(X10plot), lw=2, label='10th order')


plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
Title= "N=%i, $\sigma=%.2f$"%(N_test, sigam_test)
plt.title(Title+"(pred.)")
plt.tight_layout()
plt.ylim((-5,12))

filename_test="pred-linear_N=%i_noise%.2f.pdf"%(N_test, sigam_test)

plt.savefig(filename_test)
plt.grid()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
